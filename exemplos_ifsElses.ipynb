# %% [markdown]
# ## Exemplos

# %%
#verificação de maioridade
idade_usuario = int(input("Digite a sua idade"))
idade_usuario
# Out:
# Digite a sua idade 17
# 17

# %%
if idade_usuario >=18:
    print("Você tem idade para entrar")

else:
    print("Você não tem idade para entrar")
# Out:
# Você não tem idade para entrar

# %%
#Verificar a aprovação ou não
nota_aluno = float(input("Digite a sua média final"))
nota_aluno
# Out:
# Digite a sua média final -7
# -7.0

# %%
if nota_aluno >= 7:
    print("Parabéns, você foi aprovado(a)!")

elif nota_aluno >=5 :
    print("Você está em recuperação!")

elif nota_aluno < 0:
    print("Você tirou nota NEGATIVA???? \n P A R A B É N S!")

else:
    print("Que pena, você está reprovado(a)!")
# Out:
# Você tirou nota NEGATIVA????
#  P A R A B É N S!

# %%
#Verificando '==' e '!='
num_digitado = float(input("Digite um número entre -2 e 5 \n"))
num_digitado
# Out:
# Digite um número entre -2 e 5
#  3
# 3.0

# %%
if num_digitado == -1:
    print("Você acertou!")

else:
    print("Que pena, tente novamente!")
# Out:
# Que pena, tente novamente!

# %%
if num_digitado != 3:
    print("Que pena, tente novamente!")

else:
    print("Você acertou!")
# Out:
# Você acertou!

# %%
#Resto da divisão por um número '%'
# Par ou ímpar
num = int(input("Digite um número natural"))
if num%2 == 0:
    print(f"O {num} é par!")
else:
    print(f" O {num} é ímpar!")
# Out:
# Digite um número natural 300
# O 300 é par!

# %%
#Comparar dois números
num1 = float(input("Digite o primeiro número:"))
num2 = float(input("Digite o segundo número:"))

if num1 > num2:
    print(f"{num1} > {num2}")
elif num1 == num2:
    print(f"{num1} = {num2}")
else:
    print(f"{num2} > {num1}")
# Out:
# Digite o primeiro número: 3.14
# Digite o segundo número: 3.141
# 3.141 > 3.14

# %%
#Resolvendo uma equação do segundo grau
a = float(input("Digite o valor do coeficiente a:"))
b = float(input("Digite o valor do coeficiente b:"))
c = float(input("Digite o valor do coeficiente c:"))
delta = b**2 - 4*a*c
x1 = (-b + delta**(0.5))/(2*a)
x2 = (-b - delta**(0.5))/(2*a)
if delta < 0:
    print(f"Delta menor do zero:{delta}")
    print("Não há raíz real")
elif a == 0:
    print(f"{a} é menor que zero, insira um número diferente de zero")
elif delta == 0:
    print(f"x'= x''={x2}")
else:
    print(f"x'={x1} e x''={x2}")
# Out:
# Digite o valor do coeficiente a: 1
# Digite o valor do coeficiente b: 3
# Digite o valor do coeficiente c: 3
# Delta menor do zero:-3.0
# Não há raíz real
