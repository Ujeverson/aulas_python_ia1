# %% [markdown]
# Exercício 1:
# Crie um programa que mostre na tela

# %%
a = "Eu estou aprendendo Python"
print(a)
# Out:
# Eu estou aprendendo Python

# %% [markdown]
# Exercício 2
# Crie um programa que mostre:
#
# Meu nome é Maria
#
# Eu moro em Recife

# %%
u = "Meu nome é Ujeverson"
v = "Eu moro em Aparecida de Goiânia"
print(u)
print(v)
# Out:
# Meu nome é Ujeverson
# Eu moro em Aparecida de Goiânia

# %% [markdown]
# Exercício 3
#
# Crie duas variáveis: nome_do_aluno e idade_do_aluno.
#
# Depois mostre na tela algo assim: Meu nome é Ana e tenho 18 anos

# %%
nome_do_aluno = "Ujeverson Tavares"
idade_do_aluno = "44"
print("Meu nome é", nome_do_aluno,"e tenho",idade_do_aluno,"anos.")
# Out:
# Meu nome é Ujeverson Tavares e tenho 44 anos.

# %% [markdown]
# Crie um programa que:
# 1. Pergunte o nome do aluno.
# 2. Pergunte a cidade onde ele mora.
# 3. Mostre a frase:
# Olá João, você mora em Curitiba

# %%
entrada = input("Digite o seu nome:")
cidade = input("Qual a cidade onde você mora?")
print("Olá",entrada,"você mora em",cidade)
# Out:
# Digite o seu nome: Ujeverson Tavares
# Qual a cidade onde você mora? Aparecida de Goiânia
# Olá Ujeverson Tavares você mora em Aparecida de Goiânia
